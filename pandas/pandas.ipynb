# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Matteprov.csv')
#print(df)
#df.head(6)

#NaN - Not a Number (missing value)
#df.dropna() kastar alla rader som innehåller NaN

#fyll alla NaN med noll
df = df.fillna(0)
df['Total'] = df.sum(axis*1)
df['Betyg'] = np.where(df['Total'] >= 8, "Godkänt", "Underkänt")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-14e7ace1d6ba> in <module>
#      12 #fyll alla NaN med noll
#      13 df = df.fillna(0)
# ---> 14 df['Total'] = df.sum(axis*1)
#      15 df['Betyg'] = np.where(df['Total'] >= 8, "Godkänt", "Underkänt")
#      16 df
#
# NameError: name 'axis' is not defined

# %% [markdown]
# ## Select data
# - rader
# - kolumner

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Matteprov.csv')

df.iloc[0:3]
# Out:
#    Elev  Uppg 1  Uppg 2  Uppg 3  Uppg 4  Uppg 5
# 0   Ada     3.0     NaN     2.0     3.0     0.0
# 1  Beda     2.0     3.0     1.0     3.0     3.0
# 2  Ceda     3.0     1.0     0.0     1.0     0.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Matteprov.csv')

print(df['Elev'])
# Out:
# 0      Ada
# 1     Beda
# 2     Ceda
# 3     Deda
# 4      Eda
# 5     Feda
# 6     Geda
# 7     Heda
# 8      Ida
# 9     Keda
# 10    Leda
# 11    Meda
# Name: Elev, dtype: object

# %% [markdown]
# ## Conditionary Filtering
# - Villkorsbaserad sökning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Matteprov.csv')

df['Total'] = df.sum(axis=1)
df['Betyg'] = np.where(df['Total'] >= 8, "Godkänt", "Underkänt")

betygLista = df["Betyg"].value_counts().tolist()
labels = df["Betyg"].unique()

plt.bar(labels, betygLista, width=.4, color= ["green", "orange"])
plt.title("Antal godkända/underkända i klassen")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
